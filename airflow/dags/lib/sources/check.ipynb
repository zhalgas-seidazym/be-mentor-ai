# %%
import json
import os

with open("hh_areas_name_to_id_en.json", "r", encoding="utf-8") as f:
        areas = json.load(f)

# %%
areas
# Out:
# {'Russia': '113',
#  'Republic of Mariy El': '1620',
#  'Vilovatovo': '4228',
#  'Volzhsk': '1621',
#  'Zvenigovo': '1622',
#  'Znamenskiy': '4229',
#  'Yoshkar-Ola': '61',
#  'Kelmaksola': '4230',
#  'Kilemary': '4231',
#  'Kozmodemyansk': '1623',
#  'Krasnogorskiy (Republic of Mari El)': '4232',
#  'Krasnooktyabrskiy': '4233',
#  'Krasnyy Steklovar': '7178',
#  'Kuzhener': '4234',
#  'Kuznetsovo': '7064',
#  'Mariyets': '7080',
#  'Mari-Turek': '4235',
#  'Medvedevo': '4236',
#  'Mikhaylovka (Republic of Mari El)': '7199',
#  'Morki': '3667',
#  'Mochalishche': '7045',
#  'Novyy Toryal': '4237',
#  'Orshanka': '4238',
#  'Paranga': '4239',
#  'Pektubayevo': '7142',
#  'Privolzhskiy (Republic of Mari El)': '4240',
#  'Semenovka (Republic of Mari El)': '7012',
#  'Sernur': '4241',
#  'Silikatnyy': '7260',
#  'Sovetskiy (Republic of Mari El)': '4242',
#  'Sotnur': '7123',
#  'Surok': '7113',
#  'Suslonger': '7244',
#  'Shelanger': '11883',
#  'Yurino': '4243',
#  'Ruem': '11958',
# ...
